# %%
import pandas as pd

# %%
# Read hurtlex dataset
hurtlex = pd.read_csv("hurtlex_IT.csv")

# %%
hurtlex
# Out:
#           id pos category stereotype         lemma         level
# 0     IT2787   n       om         no             ⚣     inclusive
# 1     IT1289   n      cds         no      carretta     inclusive
# 2     IT4202   n      cds         no  qualunquista     inclusive
# 3     IT1197   n      cds         no       albagia     inclusive
# 4     IT3452   n       an         no      porcello     inclusive
# ...      ...  ..      ...        ...           ...           ...
# 6935  IT1842   n       ps        yes      incrocio     inclusive
# 6936   IT337   a      ddp        yes    insipiente  conservative
# 6937   IT198   n      asm         no     appendici     inclusive
# 6938  IT1314   n       an         no        guaire     inclusive
# 6939  IT2025   n      cds         no       crimina     inclusive
#
# [6940 rows x 6 columns]
